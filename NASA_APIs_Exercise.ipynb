# %% [markdown]
# <a href="https://colab.research.google.com/github/PMwango/PMwango/blob/main/NASA_APIs_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests pandas

# %%
import requests
from IPython.display import Image, display
# API setup
base_url = "https://api.nasa.gov/planetary/apod"
api_key = "dW40EdSDgABAh2ZjH7OraXaDMRWY3XUvZSuwJj97"
# Parameters for the GET request
params = {
    "api_key": api_key
}
# Sending the GET request
response = requests.get(base_url, params=params)

# Check the status code to ensure the request was successful
print (response.status_code)

#Parse the JSON response
data = response.json()

# Extract image URL
image_url = data["url"]  # Extract image URL

# Display the image inline in Colab
display(Image(url=image_url))

#Print Output
print (response.text)
# Out:
# 200
# <img src="https://apod.nasa.gov/apod/image/2504/ARP316_1024.jpg"/>
# ...

# %%
# Send a request to the NASA API"

import requests
import pandas as pd
# API setup
base_url = "https://api.nasa.gov/neo/rest/v1/feed"
api_key = "dW40EdSDgABAh2ZjH7OraXaDMRWY3XUvZSuwJj97"

start_date = "2025-04-01"
end_date = "2025-04-04"


# Parameters for the GET request
params = {
    "start_date" : start_date,
    "end_date" : end_date,
    "api_key" : api_key

}
# Sending the GET request
response = requests.get(base_url, params=params)

# Check the status code to ensure the request was successful
response.status_code

# Parsing the JSON Response
if response.status_code == 200:
    data = response.json()
    print(data)
    all_asteroids = []

# Loop through each date and its list of asteroids
    for date in data["near_earth_objects"]:
        for asteroid in data["near_earth_objects"][date]:
            asteroid_info = {
                "Asteroid ID": asteroid["id"],
                "Asteroid name": asteroid["name"],
                "Minimal estimated diameter (km)": asteroid["estimated_diameter"]["kilometers"]["estimated_diameter_min"],
                "Absolute_magnitude": asteroid["absolute_magnitude_h"],
                "Relative_velocity (km/s)": float(asteroid["close_approach_data"][0]["relative_velocity"]["kilometers_per_second"])
            }
            all_asteroids.append(asteroid_info)
else:
    print("API Error:", response.status_code, response.text)

# --- 4. Create DataFrame ---
df = pd.DataFrame(all_asteroids)

# --- 5. Export to CSV ---
df.to_csv("asteroid_data.csv", index=False)

# --- 6. Preview the DataFrame ---
df.head()
# print (response.text)
# print(response.url)
# Out:
# {'links': {'next': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2025-04-04&end_date=2025-04-07&detailed=false&api_key=dW40EdSDgABAh2ZjH7OraXaDMRWY3XUvZSuwJj97', 'previous': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2025-03-29&end_date=2025-04-01&detailed=false&api_key=dW40EdSDgABAh2ZjH7OraXaDMRWY3XUvZSuwJj97', 'self': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2025-04-01&end_date=2025-04-04&detailed=false&api_key=dW40EdSDgABAh2ZjH7OraXaDMRWY3XUvZSuwJj97'}, 'element_count': 68, 'near_earth_objects': {'2025-04-01': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2004034?api_key=dW40EdSDgABAh2ZjH7OraXaDMRWY3XUvZSuwJj97'}, 'id': '2004034', 'neo_reference_id': '2004034', 'name': '4034 Vishnu (1986 PA)', 'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2004034', 'absolute_magnitude_h': 18.49, 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.5327886649, 'estimated_diameter_max': 1.1913516723}, 'meters': {'estimated_diameter_m
# ...

# %%
_
